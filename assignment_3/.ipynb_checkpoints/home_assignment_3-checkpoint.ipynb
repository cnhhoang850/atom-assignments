# %% [markdown]
# # HOME ASSIGNMENT #3: SLACK API - TO GSHEET
# **Mục đích của bài Assignment**
# - Lấy thông tin các Users từ Slack của DataCracy (BTC, Mentors và Learners)
# - `**[Optional 1]**` Đưa danh sách Users lên Google Spreadsheet, để theo dõi
# - `**[Optional 2]**` Lấy thông tin Assignment Submission và số Reviews trên `#atom-assignmentnt2` và cập nhật lên Spreadsheet, để theo dõi các học viên đã nộp bài và được review
#
# **Các kiến thức sẽ áp dụng**
# - Ôn lại và luyện tập thêm về concept API (cụ thể sử dụng API Slack)
# - Trích xuất thông tin từ JSON
# - Dùng module gspread để đưa thông tin lên Google Spreadsheet

# %% [markdown]
# ## 0. Load Modules

# %%
import requests #-> Để gọi API
import re #-> Để xử lý data dạng string
from datetime import datetime as dt #-> Để xử lý data dạng datetime
import gspread #-> Để update data lên Google Spreadsheet
from gspread_dataframe import set_with_dataframe #-> Để update data lên Google Spreadsheet
import pandas as pd #-> Để update data dạng bản
import json 
from oauth2client.service_account import ServiceAccountCredentials #-> Để nhập Google Spreadsheet Credentials
import os

# %% [markdown]
# ## 1. Slack API: User List
# * Bạn có thể đọc lại về concept API [HERE](https://anhdang.gitbook.io/datacracy/atom/3-data-tools-2/3.2-spotify-api-and-postman)
# * Assignment này sẽ dùng Slack API để lấy thông tin về Learners và theo dõi các bài tập đã nộp và được review (sau đó cập nhật lên Google Spreadsheet)
# * ===> **NOTICE**: Slack API authorize bằng Bearer Token `xoxb-...-...-...` (Sẽ được cung cấp riêng)
# * Update file `env_variable.json` như trong [Assignment#2](../assignment_2/home_assignment_2.ipynb)
# * ==> Nếu bạn dùng Google Colab, upload file vào Colab ([Hướng dẫn](https://colab.research.google.com/notebooks/io.ipynb))

# %%
# !ls
# Out:
# env_variables.json  home_assignment_3.ipynb  README.md	slack-bot-key.json

# %%
with open('env_variables.json', 'r') as j:
    json_data = json.load(j)
    print(json_data)
# Out:
# {'SENDER_EMAIL': 'cnhhoang850@gmail.com', 'PWD_EMAIL': 'eetwbhkppxphpvfs', 'WEATHER_API_KEY': '8ddaf824d7e377a591bb83034fbbec1a', 'SLACK_BEARER_TOKEN': 'xoxb-1381900565698-2074738241732-2FEKCWh9z1rxh11YyIC1WOjN'}

# %%
## Load SLACK_BEARER_TOKEN
os.environ['SLACK_BEARER_TOKEN'] = json_data['SLACK_BEARER_TOKEN']

# %%
## Gọi API từ Endpoints (Input - Token được đưa vào Headers)
## Challenge: Thử gọi API này bằng Postman
endpoint = "https://slack.com/api/users.list"
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}
response_json = requests.post(endpoint, headers=headers).json() 
print(response_json)
user_dat = response_json['members']
# Out:
# {'ok': True, 'members': [{'id': 'USLACKBOT', 'team_id': 'T01B7SGGMLJ', 'name': 'slackbot', 'deleted': False, 'color': '757575', 'real_name': 'Slackbot', 'tz': 'America/Los_Angeles', 'tz_label': 'Pacific Daylight Time', 'tz_offset': -25200, 'profile': {'title': '', 'phone': '', 'skype': '', 'real_name': 'Slackbot', 'real_name_normalized': 'Slackbot', 'display_name': 'Slackbot', 'display_name_normalized': 'Slackbot', 'fields': None, 'status_text': '', 'status_emoji': '', 'status_expiration': 0, 'avatar_hash': 'sv41d8cd98f0', 'always_active': True, 'first_name': 'slackbot', 'last_name': '', 'image_24': 'https://a.slack-edge.com/80588/img/slackbot_24.png', 'image_32': 'https://a.slack-edge.com/80588/img/slackbot_32.png', 'image_48': 'https://a.slack-edge.com/80588/img/slackbot_48.png', 'image_72': 'https://a.slack-edge.com/80588/img/slackbot_72.png', 'image_192': 'https://a.slack-edge.com/80588/marketing/img/avatars/slackbot/avatar-slackbot.png', 'image_512': 'https://a.slack-edge.com/80588/img/slackbot_512.png', 'status_text_canonical': '', 'team': 'T01B7SGGMLJ'}, 'is_admin': False, 'is_owner': False, 'is_primary_owner': False, 'is_restricted': False, 'is_ultra_restricted': False, 'is_bot': False, 'is_app_user': False, 'updated': 0, 'is_email_confirmed': False}, {'id': 'U01AT4T75JB', 'team_id': 'T01B7SGGMLJ', 'name': 'loclexuan26392', 'deleted': False, 'color': '4bbe2e', 'real_name': 'Loc Le Xuan', 'tz': 'Asia/Bangkok', 'tz_label': 'Indochina Time', 'tz_offset': 25200, 'profile': {'title': '', 'phone': '', 'skype': '', 'real_name': 'Loc Le Xuan', 'real_name_normalized': 'Loc Le Xuan', 'display_name': 'Loc Le Xuan', 'display_name_normalized': 'Loc Le Xuan', 'fields': None, 'status_text': '', 'status_emoji': '', 'status_expiration': 0, 'avatar_hash': '215adf26bbc2', 'image_original': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_original.jpg', 'is_custom_image': True, 'image_24': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_24.jpg', 'image_32': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_32.jpg', 'image_48': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_48.jpg', 'image_72': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_72.jpg', 'image_192': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_192.jpg', 'image_512': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_512.jpg', 'image_1024': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_1024.jpg', 'status_text_canonical': '', 'team': 'T01B7SGGMLJ'}, 'is_admin': False, 'is_owner': False, 'is_primary_owner': False, 'is_restricted': False, 'is_ultra_restricted': False, 'is_bot': False, 'is_app_user': False, 'updated': 1600924572, 'is_email_confirmed': True}, {'id': 'U01AVDY7JET', 'team_id': 'T01B7SGGMLJ', 'name': 'locle.ds', 'deleted': False, 'color': 'e7392d', 'real_name': 'Loc Le Xuan', 'tz': 'Asia/Bangkok', 'tz_label': 'Indochina Time', 'tz_offset': 25200, 'profile': {'title': '', 'phone': '', 'skype': '', 'real_name': 'Loc Le Xuan', 'real_name_normalized': 'Loc Le Xuan', 'display_name': 'Loc Le Xuan', 'display_name_normalized': 'Loc Le Xuan', 'fields': None, 'status_text': '', 'status_emoji': '', 'status_expiration': 0, 'avatar_hash': 'e8ab87f2bc95', 'image_original': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_original.jpg', 'is_custom_image': True, 'image_24': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_24.jpg', 'image_32': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_32.jpg', 'image_48': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_48.jpg', 'image_72': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_72.jpg', 'image_192': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_ ...

# %% [markdown]
# ### TODO #1
# Hoàn tất đoạn code sau

# %%
## Loop qua JSON file và extract các thông tin quan trọng (id, name, display_name, real_name_normalized, title, phone, is_bot)
## Hint: Bạn có thể dùng Postman hoặc in user_dat JSON để xem cấu trúc (schema), dùng Ctrl+F để tìm các keys (id, name, display_name, real_name_normalized, title, phone, is_bot)
user_dict = {'user_id':[], 'name':[], 'display_name':[],'real_name':[],'title':[],'phone':[],'is_bot':[]}
for i in range(len(user_dat)):
  user_dict['user_id'].append(user_dat[i]['id'])
  user_dict['name'].append(user_dat[i]['name'])
  user_dict['display_name'].append(user_dat[i]['profile']['display_name'])
  user_dict['real_name'].append(user_dat[i]['profile']['real_name_normalized'])
  user_dict['title'].append(user_dat[i]['profile']['title'])
  user_dict['phone'].append(user_dat[i]['profile']['phone'])
  user_dict['is_bot'].append(user_dat[i]['is_bot'])

# %%
user_df = pd.DataFrame(user_dict) ## Dùng pandas để convert dictionaries thành bảng
user_df.head(10)
print(user_df) ## Chỉ in 5 dòng đầu (chủ yếu để xem cấu trúc)
# Out:
#         user_id               name       display_name            real_name  \
# 0     USLACKBOT           slackbot           Slackbot             Slackbot
# 1   U01AT4T75JB     loclexuan26392        Loc Le Xuan          Loc Le Xuan
# 2   U01AVDY7JET           locle.ds        Loc Le Xuan          Loc Le Xuan
# 3   U01BE2PR6LU     maianhdang.ftu                MAD   Dặng Huỳnh Mai Anh
# 4   U01C48T7S1J  huyenhoang.design  Thanh Huyen Hoang    Thanh Huyen Hoang
# ..          ...                ...                ...                  ...
# 64  U021NF9FMPH           ngochant                                ngochant
# 65  U021TFMH1RU      mquang.151999       Quang Nguyen         Quang Nguyen
# 66  U021Y57RMN1           lamlv723             Lâm Lê               Lam Le
# 67  U02246KN5D1  conversationslist                     /conversations.list
# 68  U0226MQ73MJ                mad                                     MAD
#
#                  title phone  is_bot
# 0                              False
# 1                              False
# 2                              False
# 3   Technical Contents         False
# 4                              False
# ..                 ...   ...     ...
# 64                              True
# 65                             False
# 66                             False
# 67                              True
# 68                              True
#
# [69 rows x 7 columns]

# %%
user_df[user_df.display_name == 'MAD'] ## Lọc thông tin của MAD, trên DataFrame (bạn có thể Google thêm)
# Out:
#        user_id            name display_name           real_name  \
# 3  U01BE2PR6LU  maianhdang.ftu          MAD  Dặng Huỳnh Mai Anh
#
#                 title phone  is_bot
# 3  Technical Contents         False

# %% [markdown]
# -------------- HẾT PHẦN BẮT BUỘC ---------------------

# %% [markdown]
# ## Option 1: Update data => Google SpreadSheet

# %% [markdown]
# ### TODO#2
# Tạo service account (output là file json), file này để cho phép ta access vào Google Spreadsheet:
#
# 1. Làm theo hướng dẫn: [Google Create a Service Account](https://support.google.com/a/answer/7378726?hl=en)
# ![google_service_account](../img/google_service_account.png)
# 2. Lưu file JSON (chứa credential về máy)
# ![gservice_acc_json](../img/gservice_acc_json.png)
# 3. Nhớ Enable [Google Drive API](https://console.cloud.google.com/marketplace/product/google/drive.googleapis.com?q=search&referrer=search&project=quickstart-313303) (Nếu bạn chạy code báo lỗi chưa enable API thì vào link trong phần lỗi để Enable, sau khi kích hoạt có thể cần vài phút để chạy được)
# ![enable_api](../img/enable_api.png)
# * ==> Upload file Gsheet Credential JSON nếu bạn dùng Colab
# * ==> Nếu bạn để key trong repo git, **NHỚ** để file json vào `.gitignore` để không bị leaked key)

# %%
# !ls
# Out:
# env_variables.json  home_assignment_3.ipynb  README.md	slack-bot-key.json

# %%
## Authorize bằng JSON
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(
    'slack-bot-key.json', scope)
gc = gspread.authorize(credentials)
print("DONE!")
# Out:
# DONE!

# %% [markdown]
# **Tạo Spreadsheet**
#
# 1. Tạo Spreadsheet trên google
# 2. Invite account trong `client_email` (file JSON Gsheet Credential bên trên) vào Spreadsheet (quyền Editor)
# ![enable_api](../img/enable_api.png)
# 3. Lấy `SPREADSHEET_KEY` (nằm trong chính URL của Spreadhstee): `https://docs.google.com/spreadsheets/d/<SPREADSHEET_KEY>/edit#gid=0`
#
# ![add_gsheet](../img/add_gsheet.png)

# %%
# ACCES GOOGLE SHEET
sheet_index_no = 0
spreadsheet_key = '1mrHOuXzCOtgsIPQcm-pg8VK6uE3DM91u-RGXO_Vfexs' # input SPREADSHEET_KEY HERE
sh = gc.open_by_key(spreadsheet_key)
worksheet = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc. 

# APPEND DATA TO SHEET
set_with_dataframe(worksheet, user_df) #-> Upload user_df vào Sheet đầu tiên trong Spreadsheet

# DONE: Bây giờ bạn có thể mở spreadsheet và kiểm tra nội dung đã update chứ

# %% [markdown]
# ![slack_user_gsheet](../img/slack_user_gsheet.png)

# %% [markdown]
# -------------- HẾT PHẦN OPTION 1 ---------------------

# %% [markdown]
# ## Option 2: Ai đã nộp bài?

# %% [markdown]
# ### Slack API: Channel List

# %%
## Gọi SLACK API để list tất cả các channel
endpoint = "https://slack.com/api/conversations.list"
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}
response = requests.post(endpoint, headers=headers).json() 
channel_ls = response['channels']

# %%
channel_ls[0] ## Thử extract record đầu tiên để xem schema  => name: general, id: C01B4PVGLVB
# Out:
# {'id': 'C01B4PVGLVB',
#  'name': 'general',
#  'is_channel': True,
#  'is_group': False,
#  'is_im': False,
#  'created': 1600856703,
#  'is_archived': False,
#  'is_general': True,
#  'unlinked': 0,
#  'name_normalized': 'general',
#  'is_shared': False,
#  'parent_conversation': None,
#  'creator': 'U01BE2PR6LU',
#  'is_ext_shared': False,
#  'is_org_shared': False,
#  'shared_team_ids': ['T01B7SGGMLJ'],
#  'pending_shared': [],
#  'pending_connected_team_ids': [],
#  'is_pending_ext_shared': False,
#  'is_member': False,
#  'is_private': False,
#  'is_mpim': False,
#  'topic': {'value': '', 'creator': '', 'last_set': 0},
#  'purpose': {'value': 'This is the one channel that will always include everyone. It’s a great spot for announcements and team-wide conversations.',
#   'creator': 'U01BE2PR6LU',
#   'last_set': 1600856703},
#  'previous_names': [],
#  'num_members': 63}

# %%
#TODO 3
for i in channel_ls:
    if i['name'] == 'atom-assignment2':
        print(i)
# Out:
# {'id': 'C021FSDN7LJ', 'name': 'atom-assignment2', 'is_channel': True, 'is_group': False, 'is_im': False, 'created': 1620677142, 'is_archived': False, 'is_general': False, 'unlinked': 0, 'name_normalized': 'atom-assignment2', 'is_shared': False, 'parent_conversation': None, 'creator': 'U01BE2PR6LU', 'is_ext_shared': False, 'is_org_shared': False, 'shared_team_ids': ['T01B7SGGMLJ'], 'pending_shared': [], 'pending_connected_team_ids': [], 'is_pending_ext_shared': False, 'is_member': True, 'is_private': False, 'is_mpim': False, 'topic': {'value': 'Assigment#2 - Mailbot, API, Web Scrapping', 'creator': 'U01BE2PR6LU', 'last_set': 1621074502}, 'purpose': {'value': 'Where learners submit assignments and give review for others', 'creator': 'U01BE2PR6LU', 'last_set': 1621074519}, 'previous_names': [], 'num_members': 39}

# %% [markdown]
# ### TODO#3
# * Tìm id của channel #atom-assignment2

# %% [markdown]
# ### Slack API: List messages trong 1 channel

# %%
endpoint = "https://slack.com/api/conversations.history"
data = {"channel": "C01U6P7LZ8F"} ## This is ID of assignment#1 channel
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}

# %%
response_json = requests.post(endpoint, data=data, headers=headers).json()
msg_ls = response_json['messages']

# %%
msg_ls[21]
# Out:
# {'client_msg_id': '16a573fd-377c-4713-9045-818f1fe64ae4',
#  'type': 'message',
#  'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0<https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585>\xa0\nTask 2:\xa0<https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb>\xa0\nTask 3:\xa0<https://github.com/vietqh/datacracy-atom-HoangQuocViet>',
#  'user': 'U01U6JM6LEB',
#  'ts': '1619226537.041400',
#  'team': 'T01B7SGGMLJ',
#  'attachments': [{'fallback': 'vietqh/datacracy-atom-HoangQuocViet',
#    'title': 'vietqh/datacracy-atom-HoangQuocViet',
#    'id': 1,
#    'color': '24292f',
#    'fields': [{'title': 'Language',
#      'value': 'Jupyter Notebook',
#      'short': True},
#     {'title': 'Last updated', 'value': '28 minutes ago', 'short': True}],
#    'bot_id': 'B01UQU8E2A3',
#    'app_unfurl_url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet',
#    'is_app_unfurl': True}],
#  'blocks': [{'type': 'rich_text',
#    'block_id': 'EHA',
#    'elements': [{'type': 'rich_text_section',
#      'elements': [{'type': 'text',
#        'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0'},
#       {'type': 'link',
#        'url': 'https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585'},
#       {'type': 'text', 'text': '\xa0\nTask 2:\xa0'},
#       {'type': 'link',
#        'url': 'https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb'},
#       {'type': 'text', 'text': '\xa0\nTask 3:\xa0'},
#       {'type': 'link',
#        'url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet'}]}]}],
#  'thread_ts': '1619226537.041400',
#  'reply_count': 1,
#  'reply_users_count': 1,
#  'latest_reply': '1620991326.023600',
#  'reply_users': ['U01V00P4S2V'],
#  'is_locked': False,
#  'subscribed': False,
#  'reactions': [{'name': 'construction',
#    'users': ['U01UTGS5ZNY', 'U01V00P4S2V'],
#    'count': 2}]}

# %%
not_learners_id = ['U01BE2PR6LU']

# %%
## Summarize all submitted assignments + reviews cnt
not_learners_id = ['U01BE2PR6LU'] # -> Remove MA from the user_id
msg_lk = []
msg_dict = {'github': [], 'reply_count': [], 'reply_users_count': [], 'reply_users': [], 'latest_reply':[] } 
for i in range(len(msg_ls)):
  ts = dt.fromtimestamp(float(msg_ls[i]['ts'])) # -> Convert timestamp Epoch thành dàng dễ đọc
  user = msg_ls[i]['user'] # -> Lấy thông tin người post messages
  if msg_ls[i]['user'] not in not_learners_id:
    if 'attachments' in msg_ls[i].keys():
      text = msg_ls[i]['text']
      github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text) #-> Submission là các message có link github
      print(msg_ls[i])
      if len(github_link) > 0: msg_dict['github'].append(github_link[0])
      if 'reply_count' in msg_ls[i].keys(): msg_dict['reply_count'].append(msg_ls[i]['reply_count']) #-> Extract số review
      if 'reply_users_count' in msg_ls[i].keys(): msg_dict['reply_users_count'].append(msg_ls[i]['reply_users_count'])
      if 'reply_users' in msg_ls[i].keys(): msg_dict['reply_users'].append(msg_ls[i]['reply_users'])
      if 'latest_reply' in msg_ls[i].keys(): msg_dict['latest_reply'].append(dt.fromtimestamp(float(msg_ls[i]['latest_reply'])))


msg_df = pd.DataFrame(msg_dict)

print(msg_df)
# Out:
# {'client_msg_id': 'D86A48D2-D953-4504-92BF-D9240B2549A8', 'type': 'message', 'text': 'Hi all,\nMình gửi lại assignment phần 1 nhé\nTask 1: <https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707|https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707>\nTask 2: <https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1|https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1>\nTask 3: <https://github.com/danhpcv/datacracy-atom-danhpcv|https://github.com/danhpcv/datacracy-atom-danhpcv>', 'user': 'U01UJ9LG5U5', 'ts': '1620622306.004700', 'team': 'T01B7SGGMLJ', 'attachments': [{'fallback': 'danhpcv/datacracy-atom-danhpcv', 'title': 'danhpcv/datacracy-atom-danhpcv', 'id': 1, 'color': '24292f', 'fields': [{'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}, {'title': 'Last updated', 'value': '17 days ago', 'short': True}], 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/danhpcv/datacracy-atom-danhpcv', 'is_app_unfurl': True}, {'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210506-060122-RC00_372298824', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'}], 'blocks': [{'type': 'rich_text', 'block_id': 'iZh8', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Hi all,\nMình gửi lại assignment phần 1 nhé\nTask 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707', 'text': 'https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1', 'text': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/danhpcv/datacracy-atom-danhpcv', 'text': 'https://github.com/danhpcv/datacracy-atom-danhpcv'}]}]}], 'thread_ts': '1620622306.004700', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621070071.003600', 'reply_users': ['U01USGKQ771', 'U01V00KHHHP'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01UJ9P1S3X'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01USGKQ771', 'U01V00KHHHP'], 'count': 2}]}
# {'client_msg_id': '246fb20c-8739-4664-9bcf-14f57aee17f7', 'type': 'message', 'text': 'Mình xin phép gửi bài Assignment 1 ạ. :D\nTask 1: <https://docs.google.com/spreadsheets/d/1j_duRwbJeKKwVVetBEPo84HGbCVmAsFUj7YdreFszTk/edit?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing>\nTask 3: <https://github.com/auslynnguyen/datacracy-atom-thunguyen>', 'user': 'U01UMC08KL2', 'ts': '1620621339.003800', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210506-060122-RC00_372298824', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': '4teEx', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mình xin phép gửi bài Assignment 1 ạ. :D\nTask 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1j_duRwbJeKKwVVetBEPo84HGbCVmAsFUj7YdreFszTk/edit?usp=sharing'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/auslynnguyen/datacracy-atom-thunguyen'}]}]}], 'thread_ts': '1620621339.003800', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621325399.000800', 'reply_users': ['U01UTGS5ZNY', 'U01UMC08KL2'], 'is_locked': False, 'subscribed': False}
# {'client_msg_id': '7857690f-4e60-4495-bc93-349c785f5ebf', 'type': 'message', 'text': 'hi mọi người, ngoài <https://www.hackerrank.com/challenges/between-two-sets/problem> mình xin phép được chia sẻ một nơi khác thực hành về Python: <https://leetcode.com/problems/count-and-say/>\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.', 'user': 'U01UMJ36QD9', 'ts': '1620455519.005200', 'team': 'T01B7SGGMLJ', 'attachments': [{'service_name': 'HackerRank', 'title': 'Between Two Sets | HackerRank', 'title_link': 'https://www.hackerrank.com/challenges/between-two-sets/problem', 'text': 'Find the number of integers that satisfies certain criteria relative to two sets.', 'fallback': 'HackerRank: Between Two Sets | HackerRank', 'thumb_url': 'https://hrcdn.net/og/default.jpg', 'from_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem', 'thumb_width': 1200, 'thumb_height': 640, 'service_icon': 'https://hrcdn.net/community-frontend/assets/favicon-ddc852f75a.png', 'id': 1, 'original_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem'}, {'title': 'Count and Say - LeetCode', 'title_link': 'https://leetcode.com/problems/count-and-say/', 'text': 'Level up your coding skills and quickly land a job. This is the best place to expand your knowledge and get prepared for your next interview.', 'fallback': 'Count and Say - LeetCode', 'image_url': 'https://leetcode.com/static/images/LeetCode_Sharing.png', 'from_url': 'https://leetcode.com/problems/count-and-say/', 'image_width': 481, 'image_height': 250, 'image_bytes': 139567, 'service_icon': 'https://leetcode.com/apple-touch-icon-57x57.png', 'service_name': 'LeetCode', 'id': 2, 'original_url': 'https://leetcode.com/problems/count-and-say/'}], 'blocks': [{'type': 'rich_text', 'block_id': 'Ip1K', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'hi mọi người, ngoài '}, {'type': 'link', 'url': 'https://www.hackerrank.com/challenges/between-two-sets/problem'}, {'type': 'text', 'text': ' mình xin phép được chia sẻ một nơi khác thực hành về Python: '}, {'type': 'link', 'url': 'https://leetcode.com/problems/count-and-say/'}, {'type': 'text', 'text': '\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.'}]}]}], 'thread_ts': '1620455519.005200', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620455803.006000', 'reply_users': ['U01UMBX2X18'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'raised_hands', 'users': ['U01V082PLN5', 'U01UMBX2X18'], 'count': 2}, {'name': 'heart', 'users': ['U01U6JQB695', 'U01V082PLN5', 'U01UJ9PRT5K', 'U01UMC0N5U2', 'U01UTGRP0HJ'], 'count': 5}, {'name': 'white_check_mark', 'users': ['U01BE2PR6LU', 'U01VB632FPS'], 'count': 2}, {'name': '+1', 'users': ['U01UMJ451V1', 'U01UJ9P1S3X', 'U01UTGRP0HJ'], 'count': 3}]}
# {'client_msg_id': 'CB7D6549-3D83-408E-A485-8DCA4C95DC4C', 'type': 'message', 'text': 'Chào mọi người, em gửi assignment 1 ạ: \n<https://github.com/hoaintp/datacracy-atom-hoaintp|https://github.com/hoaintp/datacracy-atom-hoaintp>\nHẹn gặp mọi người thứ 7 này :two_hearts:', 'user': 'U01UTGVPE7N', 'ts': '1620136546.001800', 'team': 'T01B7SGGMLJ', 'attachments': [{'fallback': 'hoaintp/datacracy-atom-hoaintp', 'title': 'hoaintp/datacracy-atom-hoaintp', 'id': 1, 'color': '24292f', 'fields': [{'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}, {'title': 'Last updated', 'value': '23 minutes ago', 'short': True}], 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/hoaintp/datacracy-atom-hoaintp', 'is_app_unfurl': True}], 'blocks': [{'type': 'rich_text', 'block_id': 'Ldw', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, em gửi assignment 1 ạ: \n'}, {'type': 'link', 'url': 'https://github.com/hoaintp/datacracy-atom-hoaintp', 'text': 'https://github.com/hoaintp/datacracy-atom-hoaintp'}, {'type': 'text', 'text': '\nHẹn gặp mọi người thứ 7 này '}, {'type': 'emoji', 'name': 'two_hearts'}]}]}], 'reactions': [{'name': 'construction', 'users': ['U01UJ9LG5U5'], 'count': 1}]}
# {'client_msg_id': 'ab6d23e2-f50e-465e-881b-1327d5ce437c', 'type': 'message', 'text': 'Em gửi Assignment 1 ạ:\n1. Task 1: <https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing|https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing>\n2. Task 2:\xa0<https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing|https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing>\n\n3. Task 3:\xa0<https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-|https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang->', 'user': 'U01U6JQB695', 'ts': '1620063678.002400', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01U6JQB695', 'ts': '1620065267.000000'}, 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210429-060047-RC00_371090719', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': '7wmK', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Em gửi Assignment 1 ạ:\n'}]}, {'type': 'rich_text_list', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Task 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing', 'text': 'https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Task 2:\xa0'}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing', 'text': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing'}, {'type': 'text', 'text': '\n'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Task 3:\xa0'}, {'type': 'link', 'url': 'https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-', 'text': 'https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-'}]}], 'style': 'ordered', 'indent': 0, 'offset': 0}]}], 'thread_ts': '1620063678.002400', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1620702606.001300', 'reply_users': ['U01UMC0N5U2', 'U01U6JQB695'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'white_check_mark', 'users': ['U01UMC0N5U2'], 'count': 1}]}
# {'client_msg_id': '8a6f0a0c-f0dc-4666-b667-0f659766908f', 'type': 'message', 'text': 'Em gửi Assignment 1 ạ:\n1. Link *Google Spreadsheet* Task 1: <https://docs.google.com/spreadsheets/d/1HaV9sUI6UQzgcRqpzkGy18XYlzcon2hWiFGuKhnz5IU/edit?usp=sharing>\n2. Link *Google Colab* Task 2: <https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing>\n3. Github: <https://github.com/saturn1101/datacracy-atom-phuong-tran>', 'user': 'U01V00KHHHP', 'ts': '1620031879.001200', 'team': 'T01B7SGGMLJ', 'attachments': [{'fallback': 'saturn1101/datacracy-atom-phuong-tran', 'title': 'saturn1101/datacracy-atom-phuong-tran', 'id': 1, 'color': '24292f', 'fields': [{'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}, {'title': 'Last updated', 'value': '6 minutes ago', 'short': True}], 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/saturn1101/datacracy-atom-phuong-tran', 'is_app_unfurl': True}, {'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210429-060047-RC00_371090719', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'rsRb', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Em gửi Assignment 1 ạ:\n'}]}, {'type': 'rich_text_list', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Link '}, {'type': 'text', 'text': 'Google Spreadsheet', 'style': {'bold': True}}, {'type': 'text', 'text': ' Task 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1HaV9sUI6UQzgcRqpzkGy18XYlzcon2hWiFGuKhnz5IU/edit?usp=sharing'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Link '}, {'type': 'text', 'text': 'Google Colab', 'style': {'bold': True}}, {'type': 'text', 'text': ' Task 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing'}]}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Github: '}, {'type': 'link', 'url': 'https://github.com/saturn1101/datacracy-atom-phuong-tran'}]}], 'style': 'ordered', 'indent': 0}]}], 'thread_ts': '1620031879.001200', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1621014686.024600', 'reply_users': ['U01UMBZHU2W'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01VB632FPS'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UMBZHU2W'], 'count': 1}]}
# {'client_msg_id': 'a206160a-3b59-44d0-a800-091897d7fcc7', 'type': 'message', 'text': 'Chào mọi người, mình gửi assignment 1 nhaa:\n<https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2>\nChúc mọi người một đầu tuần vui vẻ ^^', 'user': 'U01UMBZHU2W', 'ts': '1619420036.000800', 'team': 'T01B7SGGMLJ', 'attachments': [{'service_name': "Vy's Notion on Notion", 'title': 'Lê Thảo Vy - Assignment 1', 'title_link': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2', 'text': 'Task 1: link', 'fallback': "Vy's Notion on Notion: Lê Thảo Vy - Assignment 1", 'from_url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2', 'id': 1, 'original_url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2'}], 'blocks': [{'type': 'rich_text', 'block_id': 'E8w3f', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, mình gửi assignment 1 nhaa:\n'}, {'type': 'link', 'url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2'}, {'type': 'text', 'text': '\nChúc mọi người một đầu tuần vui vẻ ^^'}]}]}], 'thread_ts': '1619420036.000800', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621014755.025100', 'reply_users': ['U01UMJ451V1', 'U01UMBZHU2W'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'white_check_mark', 'users': ['U01UMJ451V1'], 'count': 1}]}
# {'client_msg_id': '65967e82-ee13-4c5d-8cd8-8cfec7050f5e', 'type': 'message', 'text': 'Chào mọi người, mình  gửi Assignment 1 nhé:\n<https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu>', 'user': 'U01VB63LRNC', 'ts': '1619229687.043200', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01VB63LRNC', 'ts': '1619233440.000000'}, 'attachments': [{'fallback': 'AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu', 'title': 'AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu', 'id': 1, 'color': '24292f', 'fields': [{'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}, {'title': 'Last updated', 'value': '8 minutes ago', 'short': True}], 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu', 'is_app_unfurl': True}], 'blocks': [{'type': 'rich_text', 'block_id': 'Tjy', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, mình  gửi Assignment 1 nhé:\n'}, {'type': 'link', 'url': 'https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu'}]}]}], 'thread_ts': '1619229687.043200', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620736634.003100', 'reply_users': ['U01UMJ451V1'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'white_check_mark', 'users': ['U01UMJ451V1'], 'count': 1}]}
# {'client_msg_id': '16a573fd-377c-4713-9045-818f1fe64ae4', 'type': 'message', 'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0<https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585>\xa0\nTask 2:\xa0<https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb>\xa0\nTask 3:\xa0<https://github.com/vietqh/datacracy-atom-HoangQuocViet>', 'user': 'U01U6JM6LEB', 'ts': '1619226537.041400', 'team': 'T01B7SGGMLJ', 'attachments': [{'fallback': 'vietqh/datacracy-atom-HoangQuocViet', 'title': 'vietqh/datacracy-atom-HoangQuocViet', 'id': 1, 'color': '24292f', 'fields': [{'title': 'Language', 'value': 'Jupyter Notebook', 'short': True}, {'title': 'Last updated', 'value': '28 minutes ago', 'short': True}], 'bot_id': 'B01UQU8E2A3', 'app_unfurl_url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet', 'is_app_unfurl': True}], 'blocks': [{'type': 'rich_text', 'block_id': 'EHA', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0'}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585'}, {'type': 'text', 'text': '\xa0\nTask 2:\xa0'}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb'}, {'type': 'text', 'text': '\xa0\nTask 3:\xa0'}, {'type': 'link', 'url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet'}]}]}], 'thread_ts': '1619226537.041400', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620991326.023600', 'reply_users': ['U01V00P4S2V'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'construction', 'users': ['U01UTGS5ZNY', 'U01V00P4S2V'], 'count': 2}]}
# {'client_msg_id': 'e77725c4-cccc-4ea0-a0f3-d3f8a7f434e2', 'type': 'message', 'text': 'Mình gửi bài assignment1:\nTask 1: <https://docs.google.com/spreadsheets/d/1XDHiv72ITLoY1aGYuc1LbqpVq20k72th4XRYPmqSAhI/edit?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing>\nTask 3: <https://github.com/vuthanhdatt/datacracy-atom-VuThanhDat>', 'user': 'U01V00P4S2V', 'ts': '1619216201.038200', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210422-060049-RC00_369841174', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': '5uv', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mình gửi bài assignment1:\nTask 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1XDHiv72ITLoY1aGYuc1LbqpVq20k72th4XRYPmqSAhI/edit?usp=sharing'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/vuthanhdatt/datacracy-atom-VuThanhDat'}]}]}], 'reactions': [{'name': 'construction', 'users': ['U01UMBZHU2W'], 'count': 1}]}
# {'client_msg_id': 'e08b9da8-2cce-44e0-90b9-a158203ee4cd', 'type': 'message', 'text': 'Mình nộp bài Assignment 1\nTask 1: <https://drive.google.com/file/d/1j07jiW9qIEnDAx9vhD1HqhjLFw0cDb6t/view?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1wg85ijR93tr7PDpKSEEZikRSxPWX0L9W?usp=sharing>\nTask 3: <https://github.com/TranPham-96/datacracy-atom--Pham-Le-Minh-Tran->', 'user': 'U01UTGRP0HJ', 'ts': '1619204218.034700', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01UTGRP0HJ', 'ts': '1619204274.000000'}, 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1wg85ijR93tr7PDpKSEEZikRSxPWX0L9W?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1wg85ijR93tr7PDpKSEEZikRSxPWX0L9W?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210422-060049-RC00_369841174', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1wg85ijR93tr7PDpKSEEZikRSxPWX0L9W?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'ghq', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mình nộp bài Assignment 1\nTask 1: '}, {'type': 'link', 'url': 'https://drive.google.com/file/d/1j07jiW9qIEnDAx9vhD1HqhjLFw0cDb6t/view?usp=sharing'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1wg85ijR93tr7PDpKSEEZikRSxPWX0L9W?usp=sharing'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/TranPham-96/datacracy-atom--Pham-Le-Minh-Tran-'}]}]}]}
# {'client_msg_id': 'e2ffdd15-53b3-44e8-aa5b-09aa96c6e68c', 'type': 'message', 'text': 'Em gửi bài nộp Assignment 1 dưới đây ạ. Chúc mọi người buổi tối vui vẻ!\nTask1: <https://docs.google.com/spreadsheets/d/1byVVlbyPWEIaa2uwm7D1PiJYkHNZffsSNnIdfa9W_a8/edit#gid=402624002>\nTask2: <https://colab.research.google.com/drive/1p8DoHN5_J9IAgwfgeMgpoU-s7TQTWdd9?authuser=1#scrollTo=qgcHbg2Xcq3x>\nTask3: <https://github.com/annaho124/datacracy-atom-Ho_Bao_Ngan>', 'user': 'U01UMJ451V1', 'ts': '1619196314.029300', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1p8DoHN5_J9IAgwfgeMgpoU-s7TQTWdd9?authuser=1#scrollTo=qgcHbg2Xcq3x', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1p8DoHN5_J9IAgwfgeMgpoU-s7TQTWdd9?authuser=1#scrollTo=qgcHbg2Xcq3x', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1p8DoHN5_J9IAgwfgeMgpoU-s7TQTWdd9?authuser=1#scrollTo=qgcHbg2Xcq3x'}], 'blocks': [{'type': 'rich_text', 'block_id': 'jlY3', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Em gửi bài nộp Assignment 1 dưới đây ạ. Chúc mọi người buổi tối vui vẻ!\nTask1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1byVVlbyPWEIaa2uwm7D1PiJYkHNZffsSNnIdfa9W_a8/edit#gid=402624002'}, {'type': 'text', 'text': '\nTask2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1p8DoHN5_J9IAgwfgeMgpoU-s7TQTWdd9?authuser=1#scrollTo=qgcHbg2Xcq3x'}, {'type': 'text', 'text': '\nTask3: '}, {'type': 'link', 'url': 'https://github.com/annaho124/datacracy-atom-Ho_Bao_Ngan'}]}]}], 'thread_ts': '1619196314.029300', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1620736753.003700', 'reply_users': ['U01UMBW8G8J', 'U01UMJ451V1'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'construction', 'users': ['U01V082PLN5'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UMBW8G8J', 'U01V082PLN5'], 'count': 2}]}
# {'client_msg_id': 'bf0e7389-a8f3-42f0-b661-29b617b8ab7f', 'type': 'message', 'text': 'Hi mọi người, Mình gửi bài assignment 1 bên dưới nhé! Hẹn gặp mọi người vào ngày mai\nTask 1. <https://docs.google.com/spreadsheets/d/1XH3SLX2ydh2VmABImj0CTJNldWo7PD7-E2d3J-22DAg/edit?usp=sharing>\n\nTask 2: <https://colab.research.google.com/drive/1Jf4ksc-HPykpr82JKlIPRVUUoptn_MeO?usp=sharing>\n\nTask 3: <https://github.com/minhnguyentk95/datacracy-atom-Nguyen-Thi-Kim-Minh>', 'user': 'U01UJ9M5TU5', 'ts': '1619196113.026200', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1Jf4ksc-HPykpr82JKlIPRVUUoptn_MeO?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1Jf4ksc-HPykpr82JKlIPRVUUoptn_MeO?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1Jf4ksc-HPykpr82JKlIPRVUUoptn_MeO?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'bGG0', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Hi mọi người, Mình gửi bài assignment 1 bên dưới nhé! Hẹn gặp mọi người vào ngày mai\nTask 1. '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1XH3SLX2ydh2VmABImj0CTJNldWo7PD7-E2d3J-22DAg/edit?usp=sharing'}, {'type': 'text', 'text': '\n\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1Jf4ksc-HPykpr82JKlIPRVUUoptn_MeO?usp=sharing'}, {'type': 'text', 'text': '\n\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/minhnguyentk95/datacracy-atom-Nguyen-Thi-Kim-Minh'}]}]}], 'thread_ts': '1619196113.026200', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620650715.005800', 'reply_users': ['U01UJ9MUADT'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'white_check_mark', 'users': ['U01UJ9MUADT'], 'count': 1}]}
# {'client_msg_id': 'd0e9c131-e6a2-42b6-a928-f1a4c4b1093d', 'type': 'message', 'text': 'Em gửi Assignment 1 bên dưới nha\nTask 1: <https://docs.google.com/spreadsheets/d/1Jm3AbAAT7G-U-X-Y7JWl5mE_tsKIxj2lrzORTRE77GQ/edit?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1m6OpbUUsxjs5ajLNS4yymymouXTBBA_S?usp=sharing>\nTask 3: <https://github.com/lienanh264/datacracy-atom--lien-anh->\nHẹn gặp mọi người ngày mai :D', 'user': 'U01UJ9NKX8D', 'ts': '1619192886.023900', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1m6OpbUUsxjs5ajLNS4yymymouXTBBA_S?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1m6OpbUUsxjs5ajLNS4yymymouXTBBA_S?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1m6OpbUUsxjs5ajLNS4yymymouXTBBA_S?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'Ol+', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Em gửi Assignment 1 bên dưới nha\nTask 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1Jm3AbAAT7G-U-X-Y7JWl5mE_tsKIxj2lrzORTRE77GQ/edit?usp=sharing'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1m6OpbUUsxjs5ajLNS4yymymouXTBBA_S?usp=sharing'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/lienanh264/datacracy-atom--lien-anh-'}, {'type': 'text', 'text': '\nHẹn gặp mọi người ngày mai :D'}]}]}], 'thread_ts': '1619192886.023900', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1621043899.001900', 'reply_users': ['U01UTGVPE7N'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'construction', 'users': ['U01UJ9M5TU5'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UTGVPE7N'], 'count': 1}]}
# {'client_msg_id': '1dabc185-17be-4a24-be66-017e3b866c42', 'type': 'message', 'text': 'Mình gửi link submission assignment1 nhé:\n1. <https://docs.google.com/spreadsheets/d/1f3w0cSAKtn8DmiQnop08RcrN0-lAZGG2DrbfX0Bzs2E/edit?usp=sharing|https://docs.google.com/spreadsheets/d/1f3w0cSAKtn8DmiQnop08RcrN0-lAZGG2DrbfX0Bzs2E/edit?usp=sharing>\n 2. <https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing|https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing>\n 3. <https://github.com/Lulichlam/datacracy-atom-thutrang|https://github.com/Lulichlam/datacracy-atom-thutrang>', 'user': 'U01UJ9MUADT', 'ts': '1619190217.023200', 'team': 'T01B7SGGMLJ', 'edited': {'user': 'U01UJ9MUADT', 'ts': '1619227814.000000'}, 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'DGXpt', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Mình gửi link submission assignment1 nhé:\n'}]}, {'type': 'rich_text_list', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1f3w0cSAKtn8DmiQnop08RcrN0-lAZGG2DrbfX0Bzs2E/edit?usp=sharing', 'text': 'https://docs.google.com/spreadsheets/d/1f3w0cSAKtn8DmiQnop08RcrN0-lAZGG2DrbfX0Bzs2E/edit?usp=sharing'}]}], 'style': 'ordered', 'indent': 0, 'offset': 0}, {'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': ' 2. '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing', 'text': 'https://colab.research.google.com/drive/1EPTXQmiZGmKFbo7IRVSUysXdn-c-Nqp0?usp=sharing'}, {'type': 'text', 'text': '\n 3. '}, {'type': 'link', 'url': 'https://github.com/Lulichlam/datacracy-atom-thutrang', 'text': 'https://github.com/Lulichlam/datacracy-atom-thutrang'}]}]}], 'thread_ts': '1619190217.023200', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620744408.005500', 'reply_users': ['U01UTGRMGEQ'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'white_check_mark', 'users': ['U01UTGRMGEQ'], 'count': 1}]}
# {'client_msg_id': 'FA5E60C5-2B06-4535-8305-8688CC9AB72F', 'type': 'message', 'text': 'Chào mọi người, mình gửi assignmen 1 nhé, chúc mọi người ngủ ngon. Hẹn gặp mọi người vào sáng mai\nTask 1: <https://drive.google.com/file/d/1rAXfZVmqwuHAWBetUQdOCjBkdTQr1blH/view?usp=sharing|https://drive.google.com/file/d/1rAXfZVmqwuHAWBetUQdOCjBkdTQr1blH/view?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing|https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing>\nTask 3: <https://github.com/tamle1012/datacracy-atom--tamle-|https://github.com/tamle1012/datacracy-atom--tamle->', 'user': 'U01VB6AT4G0', 'ts': '1619189359.022500', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'jxn', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, mình gửi assignmen 1 nhé, chúc mọi người ngủ ngon. Hẹn gặp mọi người vào sáng mai\nTask 1: '}, {'type': 'link', 'url': 'https://drive.google.com/file/d/1rAXfZVmqwuHAWBetUQdOCjBkdTQr1blH/view?usp=sharing', 'text': 'https://drive.google.com/file/d/1rAXfZVmqwuHAWBetUQdOCjBkdTQr1blH/view?usp=sharing'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing', 'text': 'https://colab.research.google.com/drive/1Mh5w_fiTvYcSvWvGvy6v4Q5In14ek38g?usp=sharing'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/tamle1012/datacracy-atom--tamle-', 'text': 'https://github.com/tamle1012/datacracy-atom--tamle-'}]}]}], 'thread_ts': '1619189359.022500', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620748698.006600', 'reply_users': ['U01UJ9PA0MB'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': 'slightly_smiling_face', 'users': ['U01UTGRQS9J'], 'count': 1}, {'name': 'construction', 'users': ['U01UTGRQS9J'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UJ9PA0MB'], 'count': 1}]}
# {'client_msg_id': '15e261ea-5ad4-46e1-af66-53aa8fb1515d', 'type': 'message', 'text': 'Hi all,\nMình gửi assignment phần 1 nhé, chúc mọi người cuối tuần vui vẻ\nTask 1: <https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707>\nTask 2: <https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1>\nTask 3: <https://github.com/danhpcv/datacracy-atom-danhpcv>', 'user': 'U01UJ9LG5U5', 'ts': '1619178288.011300', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'}], 'blocks': [{'type': 'rich_text', 'block_id': '=ML', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Hi all,\nMình gửi assignment phần 1 nhé, chúc mọi người cuối tuần vui vẻ\nTask 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707'}, {'type': 'text', 'text': '\nTask 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'}, {'type': 'text', 'text': '\nTask 3: '}, {'type': 'link', 'url': 'https://github.com/danhpcv/datacracy-atom-danhpcv'}]}]}], 'thread_ts': '1619178288.011300', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620878029.000600', 'reply_users': ['U01UJ9PA0MB'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UJ9PA0MB'], 'count': 1}]}
# {'client_msg_id': 'f378f3d7-bcd9-41bb-ab68-a5a05c46dceb', 'type': 'message', 'text': 'Xin chào mọi người, đây là Assignment1 của mình. Chúc mọi người buổi tối cuối tuần vui.\n1. Link *Google Spreadsheet* - Task 1:\n<https://docs.google.com/spreadsheets/d/1AeAstzQdzJkcIy8TV3LOYwcM5ZKlzSXItqlBFKgdPTg/edit?usp=sharing>\n2. Link *Google Colab* - Task 2:\n<https://colab.research.google.com/drive/1G2crJ2TDwu4UlNUtyWZyuugBwTE5MOAF?usp=sharing>\n3. *Github:* Link tới repo:\n<https://github.com/ngttnguyen/datacracy-atom-NguyenThaoNguyen>', 'user': 'U01UTGT8CVA', 'ts': '1619169829.008700', 'team': 'T01B7SGGMLJ', 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1G2crJ2TDwu4UlNUtyWZyuugBwTE5MOAF?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1G2crJ2TDwu4UlNUtyWZyuugBwTE5MOAF?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1G2crJ2TDwu4UlNUtyWZyuugBwTE5MOAF?usp=sharing'}], 'blocks': [{'type': 'rich_text', 'block_id': 'M4n', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Xin chào mọi người, đây là Assignment1 của mình. Chúc mọi người buổi tối cuối tuần vui.\n1. Link '}, {'type': 'text', 'text': 'Google Spreadsheet', 'style': {'bold': True}}, {'type': 'text', 'text': ' - Task 1:\n'}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1AeAstzQdzJkcIy8TV3LOYwcM5ZKlzSXItqlBFKgdPTg/edit?usp=sharing'}, {'type': 'text', 'text': '\n2. Link '}, {'type': 'text', 'text': 'Google Colab ', 'style': {'bold': True}}, {'type': 'text', 'text': '- Task 2:\n'}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1G2crJ2TDwu4UlNUtyWZyuugBwTE5MOAF?usp=sharing'}, {'type': 'text', 'text': '\n3. '}, {'type': 'text', 'text': 'Github:', 'style': {'bold': True}}, {'type': 'text', 'text': ' Link tới repo:\n'}, {'type': 'link', 'url': 'https://github.com/ngttnguyen/datacracy-atom-NguyenThaoNguyen'}]}]}], 'thread_ts': '1619169829.008700', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621005902.023900', 'reply_users': ['U01UMBW8G8J', 'U01UTGT8CVA'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UMBW8G8J'], 'count': 1}]}
# {'type': 'message', 'text': 'Chào mọi người, em gửi bài tập tuần 1 ạ.\n1. Link Google Sheet - Task 1: <https://docs.google.com/spreadsheets/d/1Azqdc8rOrbAZEFlgXTGS2vfHNbhDsF7NbFgLRR1Z854/edit?usp=sharing>\n2. Link Google Colab - Task 2: <https://colab.research.google.com/drive/1yklp9Nvz524bvM_T891mwHgTSrVtKXld?usp=sharing>\n3. Link Github Repo - Task 3: <https://github.com/cnhhoang850/datacracy-atom-cao-nguyen-huy-hoang>', 'upload': False, 'blocks': [{'type': 'rich_text', 'block_id': 'GxN1L', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Chào mọi người, em gửi bài tập tuần 1 ạ.\n1. Link Google Sheet - Task 1: '}, {'type': 'link', 'url': 'https://docs.google.com/spreadsheets/d/1Azqdc8rOrbAZEFlgXTGS2vfHNbhDsF7NbFgLRR1Z854/edit?usp=sharing'}, {'type': 'text', 'text': '\n2. Link Google Colab - Task 2: '}, {'type': 'link', 'url': 'https://colab.research.google.com/drive/1yklp9Nvz524bvM_T891mwHgTSrVtKXld?usp=sharing'}, {'type': 'text', 'text': '\n3. Link Github Repo - Task 3: '}, {'type': 'link', 'url': 'https://github.com/cnhhoang850/datacracy-atom-cao-nguyen-huy-hoang'}]}]}], 'user': 'U01UJ9M3P1T', 'ts': '1619163505.004100', 'edited': {'user': 'U01UJ9M3P1T', 'ts': '1619163550.000000'}, 'client_msg_id': 'caf1a163-1a5a-47d9-ae4b-2f93b307143f', 'thread_ts': '1619163505.004100', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620655127.006300', 'reply_users': ['U01UJ9MUADT'], 'is_locked': False, 'subscribed': False, 'attachments': [{'title': 'Google Colaboratory', 'title_link': 'https://colab.research.google.com/drive/1yklp9Nvz524bvM_T891mwHgTSrVtKXld?usp=sharing', 'fallback': 'Google Colaboratory', 'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png', 'from_url': 'https://colab.research.google.com/drive/1yklp9Nvz524bvM_T891mwHgTSrVtKXld?usp=sharing', 'image_width': 250, 'image_height': 250, 'image_bytes': 4534, 'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210421-060109-RC00_369621175', 'service_name': 'colab.research.google.com', 'id': 1, 'original_url': 'https://colab.research.google.com/drive/1yklp9Nvz524bvM_T891mwHgTSrVtKXld?usp=sharing'}], 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01UJ9MUADT'], 'count': 1}]}
# {'client_msg_id': '77eeef15-fec5-4949-87ca-ed110c23596a', 'type': 'message', 'text': 'Xin chào mọi người. Đây là Home assignment week 1 của mình. Hẹn gặp lại mọi người vào ngày mai\n<https://bit.ly/3azLWIF>', 'user': 'U01UJ9PA0MB', 'ts': '1619142476.001500', 'team': 'T01B7SGGMLJ', 'attachments': [{'service_name': 'GitHub', 'title': 'hongdoi/datacracy-atom--doi-thi-hong-', 'title_link': 'https://bit.ly/3azLWIF', 'text': 'Contribute to hongdoi/datacracy-atom--doi-thi-hong- development by creating an account on GitHub.', 'fallback': 'GitHub: hongdoi/datacracy-atom--doi-thi-hong-', 'image_url': 'https://opengraph.githubassets.com/1861da571a5e9c6a4335037847f57e41ee1739803e25915dfefcc73fe92787b9/hongdoi/datacracy-atom--doi-thi-hong-', 'from_url': 'https://bit.ly/3azLWIF', 'image_width': 500, 'image_height': 250, 'image_bytes': 37221, 'service_icon': 'https://github.com/favicon.ico', 'id': 1, 'original_url': 'https://bit.ly/3azLWIF'}], 'blocks': [{'type': 'rich_text', 'block_id': 'jZ=', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'text', 'text': 'Xin chào mọi người. Đây là Home assignment week 1 của mình. Hẹn gặp lại mọi người vào ngày mai\n'}, {'type': 'link', 'url': 'https://bit.ly/3azLWIF'}]}]}], 'thread_ts': '1619142476.001500', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1620882970.001100', 'reply_users': ['U01VB632FPS', 'U01UJ9PA0MB'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}, {'name': 'construction', 'users': ['U01VB632FPS'], 'count': 1}]}
# {'client_msg_id': '9e9c6642-63c6-445c-b25c-fd0b8a387a47', 'type': 'message', 'text': '<https://github.com/interphuoc/datacracy-atom--phuochuynh-> : Dạ em xin phép gửi link Home Assignment 1 của em. Chúc mọi người ngủ ngon ^^', 'user': 'U01V082PLN5', 'ts': '1619110207.003300', 'team': 'T01B7SGGMLJ', 'attachments': [{'service_name': 'GitHub', 'title': 'interphuoc/datacracy-atom--phuochuynh-', 'title_link': 'https://github.com/interphuoc/datacracy-atom--phuochuynh-', 'text': 'Contribute to interphuoc/datacracy-atom--phuochuynh- development by creating an account on GitHub.', 'fallback': 'GitHub: interphuoc/datacracy-atom--phuochuynh-', 'image_url': 'https://opengraph.githubassets.com/230add8571107ff4f52c97f56d185e5b5bc95cc277d84cab3a6d6a4e6caf9e08/interphuoc/datacracy-atom--phuochuynh-', 'from_url': 'https://github.com/interphuoc/datacracy-atom--phuochuynh-', 'image_width': 500, 'image_height': 250, 'image_bytes': 91203, 'service_icon': 'https://a.slack-edge.com/80588/img/unfurl_icons/github.png', 'id': 1, 'original_url': 'https://github.com/interphuoc/datacracy-atom--phuochuynh-'}], 'blocks': [{'type': 'rich_text', 'block_id': 'PZH', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://github.com/interphuoc/datacracy-atom--phuochuynh-'}, {'type': 'text', 'text': ' : Dạ em xin phép gửi link Home Assignment 1 của em. Chúc mọi người ngủ ngon ^^'}]}]}], 'thread_ts': '1619110207.003300', 'reply_count': 1, 'reply_users_count': 1, 'latest_reply': '1620967043.022200', 'reply_users': ['U01V00JK9LH'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV'], 'count': 1}, {'name': 'construction', 'users': ['U01UMJ5AQ0K'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01V00JK9LH'], 'count': 1}]}
# {'client_msg_id': 'f37184b6-5b1d-4e2e-a0ef-72106846683c', 'type': 'message', 'text': '<https://github.com/duongphannamhung/datacracy-atom-duongphannamhung> : Em gửi link assignment 1 của mình. Chúc mọi người nghỉ lễ vui vẻ nha :smiling_face_with_3_hearts:', 'user': 'U01UMJ5AQ0K', 'ts': '1618984834.000800', 'team': 'T01B7SGGMLJ', 'attachments': [{'service_name': 'GitHub', 'title': 'duongphannamhung/datacracy-atom-duongphannamhung', 'title_link': 'https://github.com/duongphannamhung/datacracy-atom-duongphannamhung', 'text': 'Hôm nay, mình học DATAcracy. Contribute to duongphannamhung/datacracy-atom-duongphannamhung development by creating an account on GitHub.', 'fallback': 'GitHub: duongphannamhung/datacracy-atom-duongphannamhung', 'image_url': 'https://opengraph.githubassets.com/42dc9d8f2daadd198aa1736e0a5b85b878bebc00aaf8fd5131f1d4174876aefc/duongphannamhung/datacracy-atom-duongphannamhung', 'from_url': 'https://github.com/duongphannamhung/datacracy-atom-duongphannamhung', 'image_width': 500, 'image_height': 250, 'image_bytes': 116968, 'service_icon': 'https://a.slack-edge.com/80588/img/unfurl_icons/github.png', 'id': 1, 'original_url': 'https://github.com/duongphannamhung/datacracy-atom-duongphannamhung'}], 'blocks': [{'type': 'rich_text', 'block_id': '2vN', 'elements': [{'type': 'rich_text_section', 'elements': [{'type': 'link', 'url': 'https://github.com/duongphannamhung/datacracy-atom-duongphannamhung'}, {'type': 'text', 'text': ' : Em gửi link assignment 1 của mình. Chúc mọi người nghỉ lễ vui vẻ nha '}, {'type': 'emoji', 'name': 'smiling_face_with_3_hearts'}]}]}], 'thread_ts': '1618984834.000800', 'reply_count': 2, 'reply_users_count': 2, 'latest_reply': '1621129563.000800', 'reply_users': ['U01V00JK9LH', 'U01UJ9PRT5K'], 'is_locked': False, 'subscribed': False, 'reactions': [{'name': '+1', 'users': ['U01V00LQ7EV', 'U01U6JQB695', 'U01UJ9MUADT', 'U01UEJFMUSJ', 'U01UJ9P1S3X', 'U01BE2PR6LU', 'U01UJ9PRT5K'], 'count': 7}, {'name': 'wave', 'users': ['U01UJ9M5TU5', 'U01UEJFMUSJ', 'U01BE2PR6LU', 'U01VB632FPS'], 'count': 4}, {'name': 'construction', 'users': ['U01UJ9PRT5K'], 'count': 1}, {'name': 'white_check_mark', 'users': ['U01V00JK9LH', 'U01UJ9PRT5K'], 'count': 2}]}
#                                    github  reply_count  reply_users_count  \
# 0             https://github.com/danhpcv/            2                  2
# 1        https://github.com/auslynnguyen/            2                  2
# 2             https://github.com/hoaintp/            1                  1
# 3         https://github.com/Tenderriver/            2                  2
# 4          https://github.com/saturn1101/            1                  1
# 5   https://github.com/AnhThuNguyenHuynh/            2                  2
# 6              https://github.com/vietqh/            1                  1
# 7         https://github.com/vuthanhdatt/            1                  1
# 8         https://github.com/TranPham-96/            2                  2
# 9           https://github.com/annaho124/            1                  1
# 10     https://github.com/minhnguyentk95/            1                  1
# 11         https://github.com/lienanh264/            1                  1
# 12          https://github.com/Lulichlam/            1                  1
# 13          https://github.com/tamle1012/            1                  1
# 14            https://github.com/danhpcv/            2                  2
# 15         https://github.com/ngttnguyen/            1                  1
# 16        https://github.com/cnhhoang850/            2                  2
# 17         https://github.com/interphuoc/            1                  1
# 18   https://github.com/duongphannamhung/            2                  2
#
#                    reply_users               latest_reply
# 0   [U01USGKQ771, U01V00KHHHP] 2021-05-15 16:14:31.003600
# 1   [U01UTGS5ZNY, U01UMC08KL2] 2021-05-18 15:09:59.000800
# 2                [U01UMBX2X18] 2021-05-08 13:36:43.006000
# 3   [U01UMC0N5U2, U01U6JQB695] 2021-05-11 10:10:06.001300
# 4                [U01UMBZHU2W] 2021-05-15 00:51:26.024600
# 5   [U01UMJ451V1, U01UMBZHU2W] 2021-05-15 00:52:35.025100
# 6                [U01UMJ451V1] 2021-05-11 19:37:14.003100
# 7                [U01V00P4S2V] 2021-05-14 18:22:06.023600
# 8   [U01UMBW8G8J, U01UMJ451V1] 2021-05-11 19:39:13.003700
# 9                [U01UJ9MUADT] 2021-05-10 19:45:15.005800
# 10               [U01UTGVPE7N] 2021-05-15 08:58:19.001900
# 11               [U01UTGRMGEQ] 2021-05-11 21:46:48.005500
# 12               [U01UJ9PA0MB] 2021-05-11 22:58:18.006600
# 13               [U01UJ9PA0MB] 2021-05-13 10:53:49.000600
# 14  [U01UMBW8G8J, U01UTGT8CVA] 2021-05-14 22:25:02.023900
# 15               [U01UJ9MUADT] 2021-05-10 20:58:47.006300
# 16  [U01VB632FPS, U01UJ9PA0MB] 2021-05-13 12:16:10.001100
# 17               [U01V00JK9LH] 2021-05-14 11:37:23.022200
# 18  [U01V00JK9LH, U01UJ9PRT5K] 2021-05-16 08:46:03.000800

# %% [markdown]
# ### TODO#4
#
# * Tạo thành 1 bảng chứa các thông tin trên và update lên Spreadsheet (Sheet: Assignment#2 Submission)

# %%
## Summarize all submitted assignments + reviews cnt
not_learners_id = ['U01BE2PR6LU'] # -> Remove MA from the user_id
msg_lk = []
msg_dict = {'github': [], 'reply_count': [], 'reply_users_count': [], 'reply_users': [], 'latest_reply':[] } 
for i in range(len(msg_ls)):
  ts = dt.fromtimestamp(float(msg_ls[i]['ts'])) # -> Convert timestamp Epoch thành dàng dễ đọc
  user = msg_ls[i]['user'] # -> Lấy thông tin người post messages
  if msg_ls[i]['user'] not in not_learners_id:
    if 'attachments' in msg_ls[i].keys():
      text = msg_ls[i]['text']
      github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text) #-> Submission là các message có link github
      if len(github_link) > 0: msg_dict['github'].append(github_link[0])
      if 'reply_count' in msg_ls[i].keys(): msg_dict['reply_count'].append(msg_ls[i]['reply_count']) #-> Extract số review
      if 'reply_users_count' in msg_ls[i].keys(): msg_dict['reply_users_count'].append(msg_ls[i]['reply_users_count'])
      if 'reply_users' in msg_ls[i].keys(): msg_dict['reply_users'].append(msg_ls[i]['reply_users'])
      if 'latest_reply' in msg_ls[i].keys(): msg_dict['latest_reply'].append(dt.fromtimestamp(float(msg_ls[i]['latest_reply'])))


msg_df = pd.DataFrame(msg_dict)

print(msg_df.head(20))

# ACCES GOOGLE SHEET
sheet_index_no = 2
spreadsheet_key = '1mrHOuXzCOtgsIPQcm-pg8VK6uE3DM91u-RGXO_Vfexs' # input SPREADSHEET_KEY HERE
sh = gc.open_by_key(spreadsheet_key)
worksheet2 = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc. 
set_with_dataframe(worksheet2, msg_df)
# Out:
#                                    github  reply_count  reply_users_count  \
# 0             https://github.com/danhpcv/            2                  2
# 1        https://github.com/auslynnguyen/            2                  2
# 2             https://github.com/hoaintp/            1                  1
# 3         https://github.com/Tenderriver/            2                  2
# 4          https://github.com/saturn1101/            1                  1
# 5   https://github.com/AnhThuNguyenHuynh/            2                  2
# 6              https://github.com/vietqh/            1                  1
# 7         https://github.com/vuthanhdatt/            1                  1
# 8         https://github.com/TranPham-96/            2                  2
# 9           https://github.com/annaho124/            1                  1
# 10     https://github.com/minhnguyentk95/            1                  1
# 11         https://github.com/lienanh264/            1                  1
# 12          https://github.com/Lulichlam/            1                  1
# 13          https://github.com/tamle1012/            1                  1
# 14            https://github.com/danhpcv/            2                  2
# 15         https://github.com/ngttnguyen/            1                  1
# 16        https://github.com/cnhhoang850/            2                  2
# 17         https://github.com/interphuoc/            1                  1
# 18   https://github.com/duongphannamhung/            2                  2
#
#                  latest_reply
# 0  2021-05-15 16:14:31.003600
# 1  2021-05-18 15:09:59.000800
# 2  2021-05-08 13:36:43.006000
# 3  2021-05-11 10:10:06.001300
# 4  2021-05-15 00:51:26.024600
# 5  2021-05-15 00:52:35.025100
# 6  2021-05-11 19:37:14.003100
# 7  2021-05-14 18:22:06.023600
# 8  2021-05-11 19:39:13.003700
# 9  2021-05-10 19:45:15.005800
# 10 2021-05-15 08:58:19.001900
# 11 2021-05-11 21:46:48.005500
# 12 2021-05-11 22:58:18.006600
# 13 2021-05-13 10:53:49.000600
# 14 2021-05-14 22:25:02.023900
# 15 2021-05-10 20:58:47.006300
# 16 2021-05-13 12:16:10.001100
# 17 2021-05-14 11:37:23.022200
# 18 2021-05-16 08:46:03.000800
# --------------------------------------------------------------------------
# AttributeError                           Traceback (most recent call last)
# <ipython-input-173-6e5d042c1463> in <module>
#      26 sh = gc.open_by_key(spreadsheet_key)
#      27 worksheet2 = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc.
# ---> 28 set_with_dataframe(worksheet2, msg_df)
#
# ~/.local/lib/python3.9/site-packages/gspread_dataframe.py in set_with_dataframe(worksheet, dataframe, row, col, include_index, include_column_header, resize, allow_formulas, string_escaping)
#     280         worksheet.resize(y, x)
#     281     else:
# --> 282         _resize_to_minimum(worksheet, y, x)
#     283
#     284     updates = []
#
# ~/.local/lib/python3.9/site-packages/gspread_dataframe.py in _resize_to_minimum(worksheet, rows, cols)
#      99     Both rows and cols are optional.
#     100     """
# --> 101     current_rows, current_cols = (worksheet.row_count, worksheet.col_count)
#     102     desired_rows, desired_cols = (rows, cols)
#     103     if desired_rows is not None and desired_rows <= current_rows:
#
# AttributeError: 'NoneType' object has no attribute 'row_count'

# %% [markdown]
# -------------- HẾT PHẦN OPTION 2 ---------------------
